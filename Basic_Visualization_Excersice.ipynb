# %% [markdown]
# ### Importing the Required Libruaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Read The `auto-mpg.csv` file using Pandas

# %%
data=pd.read_csv("F:/data science/Basic_visualizations_assignment/Auto_mpg_visualization/auto-mpg.csv")

# %% [markdown]
# ## Check the Dtypes

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %% [markdown]
# ### Univariate Data Analysis:
#
# Univariate data analysis is the simplest form of data analysis. As the name suggests, it deals with one variable. It doesn’t find cause and effect or relationship between variables. The purpose of univariate data analysis is to summarize and describe one data or one variable.

# %% [markdown]
# ### List out the Univariate Plots ( Numerical Plots):

# %% [raw]
# Answer:
# histogram
# boxplot
# line chart
# distplot
# jointplot

# %% [markdown]
# ### List out the Univeriate Plots (Categorical Plots):

# %% [raw]
# Answer:
# pie chart
# bar chart
# countplot
# violin plot

# %% [markdown]
# ## Note:
#
# - You can use Pandas or Matplotlib plots for univariate based plotting
# - Write the Observations for each plot and make a conclusion finally

# %% [markdown]
# ### Draw the Different Univariate plots for All the Numerical variables in the Dataset (Auto MPG)

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.shape
# Out:
# (398, 9)

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %% [markdown]
# ## mpg

# %%
plt.figure()
plt.hist(data["mpg"])
# Out:
# (array([13., 78., 73., 61., 54., 48., 38., 22.,  5.,  6.]),
#  array([ 9.  , 12.76, 16.52, 20.28, 24.04, 27.8 , 31.56, 35.32, 39.08,
#         42.84, 46.6 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### A large no.of cars are having mpg valueof 12to 20.

# %% [markdown]
# ## cylinders

# %%
plt.figure()
sns.distplot(data["cylinders"])
# Out:
# C:\Users\Lenono\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cylinders', ylabel='Density'>

# %%
plt.figure()
sns.violinplot(data["cylinders"],color='red')
plt.show()
# Out:
# C:\Users\Lenono\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### The cars with 4 cylinders are more and next comes cars with 8 cylinders.

# %% [markdown]
# ## displacement

# %%
plt.figure()
sns.distplot(data["displacement"],kde=False)
plt.show()
# Out:
# C:\Users\Lenono\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure()
sns.boxplot(data["displacement"],color='green')
plt.show()
# Out:
# C:\Users\Lenono\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### More number of cars are having displacement around 100

# %% [markdown]
# ## horsepower

# %%
plt.figure(figsize=(30,8))
sns.histplot(data["horsepower"])
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Count'>

# %%
x=np.arange(0,10)
sns.barplot(y=x,x=data["horsepower"][0:10])
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %% [markdown]
# ## weight

# %%
sns.distplot(data["weight"])
# Out:
# C:\Users\Lenono\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.histplot(data["weight"])
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %% [markdown]
# ### Lareg number of cars are having weight of around 2000 to 2400

# %% [markdown]
# ## acceleration

# %%
sns.histplot(data["acceleration"],color='red',palette='Set3')
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='Count'>

# %% [markdown]
# ### More number of cars re having acceleration of 15.

# %% [markdown]
# ## model year

# %%
sns.distplot(data["model year"])
# Out:
# C:\Users\Lenono\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='model year', ylabel='Density'>

# %% [markdown]
# ## origin

# %%
sns.countplot(data["origin"])
# Out:
# C:\Users\Lenono\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='origin', ylabel='count'>

# %%
a=data["origin"].value_counts()

# %%
labels=['1','3','2']
explode=(0.1,0,0)

# %%
plt.pie(a,labels=labels,explode=explode,shadow=True,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2290ba0caf0>,
# ...
#  [Text(-0.46140690822606, 1.1077471124048432, '1'),
#   Text(-0.17293561388226758, -1.0863209808574827, '3'),
#   Text(0.9363126752779499, -0.5773374871891209, '2')],
#  [Text(-0.269154029798535, 0.6461858155694917, '62.6%'),
#   Text(-0.09432851666305503, -0.5925387168313542, '19.8%'),
#   Text(0.5107160046970636, -0.3149113566486114, '17.6%')])

# %% [markdown]
# ### Draw the different Univariate plots for All the Categorical variables in the Dataset (Auto MPG)

# %% [markdown]
# ## car name

# %%
data["car name"].value_counts()[0:10].plot.bar()
# Out:
# <AxesSubplot:>

# %%
x=data["car name"].value_counts()[0:5]

# %%
labels=['ford pinto','amc matador','ford maverick','toyota corolla ','peugeot']
explode=(0.1,0,0,0,0)
plt.pie(x,labels=labels,shadow=True,explode=explode,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2290bb3c760>,
# ...
#  [Text(0.8747623667495497, 0.8214565123722171, 'ford pinto'),
#   Text(-0.5894094518681141, 0.9287607324001856, 'amc matador'),
#   Text(-1.0654414787782402, -0.27355886989611017, 'ford maverick'),
#   Text(-0.06906955709217558, -1.097829402176445, 'toyota corolla '),
#   Text(0.9639373540021146, -0.5299290306818474, 'peugeot')],
#  [Text(0.5102780472705706, 0.4791829655504599, '24.0%'),
#   Text(-0.3214960646553349, 0.5065967631273739, '20.0%'),
#   Text(-0.5811498975154037, -0.14921392903424188, '20.0%'),
#   Text(-0.0376743038684594, -0.5988160375507882, '20.0%'),
#   Text(0.5257840112738806, -0.2890521985537349, '16.0%')])

# %% [markdown]
# ### Bivariate analysis:-
#
# is performed to find the relationship between each variable in the dataset and the target variable of interest (or) using 2 variables and finding the relationship between them

# %% [markdown]
# ### List out the Bivariate Numerical plots

# %% [raw]
# - Numeric to Numeric based plots:
#
# scatter plot
# jointplot

# %% [raw]
# -  Categorical to Numerical Plots:
#       boxplot
#       violinplot

# %% [raw]
# - Categorical to Categorical Plots:
# barplot

# %% [markdown]
# ## Note:
# - Use Seaborn plots for Bivariate plots
# - Write the Observations for each plot and make a conclusion finally

# %% [markdown]
# ### Draw the different Bivariate plots for All the Numerical variables in the Dataset

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## My target variable is Origin

# %%
plt.figure(figsize=(24,8))
plt.subplot(2,2,1)
sns.barplot(data["origin"],data["mpg"],data=data)

plt.subplot(2,2,2)
sns.boxplot(y=data["cylinders"],x=data["origin"],data=data)

plt.subplot(2,2,3)
sns.scatterplot(x=data["origin"],y=data["displacement"],data=data)

plt.subplot(2,2,4)
sns.lineplot(x=data["origin"],y=data["horsepower"],data=data)
# Out:
# C:\Users\Lenono\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='origin', ylabel='horsepower'>

# %%
plt.figure(figsize=(24,8))

plt.subplot(2,2,1)
sns.violinplot(x=data["origin"],y=data["weight"],data=data)

plt.subplot(2,2,2)
sns.boxplot(x=data["origin"],y=data["acceleration"],data=data)

plt.subplot(2,2,3)
sns.lineplot(x=data["origin"],y=data["model year"],data=data)

plt.subplot(2,2,4)
sns.barplot(x=data["origin"],y=data["car name"][0:10],data=data)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='car name'>

# %% [markdown]
# ### Draw the Bivariate plots for combination of Numerical and Categorical variables in the Dataset

# %% [markdown]
# ## Plot the no cars having cylinders

# %%
a=data["cylinders"].value_counts()

# %%
a
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
labels=['4cylinders','8','6','3','5']
explode=(0,0,0,0.1,0)

# %%
plt.pie(a,labels=labels,explode=explode,data=data,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x22912401940>,
# ...
#  [Text(-0.04340268967550522, 1.0991433967089699, '4cylinders'),
#   Text(-0.6906767581881664, -0.8561341108136535, '8'),
#   Text(0.7869722585138125, -0.7685536183830438, '6'),
#   Text(1.1962635542928013, -0.09462298172618668, '3'),
#   Text(1.0996915986507076, -0.026045879847893992, '5')],
#  [Text(-0.023674194368457392, 0.5995327618412563, '51.3%'),
#   Text(-0.37673277719354525, -0.4669822422619928, '25.9%'),
#   Text(0.4292575955529886, -0.4192110645725693, '21.1%'),
#   Text(0.6978204066708007, -0.05519673934027555, '1.0%'),
#   Text(0.5998317810822041, -0.014206843553396721, '0.8%')])

# %% [markdown]
# ### 51.3% cars are having 8 cylinders and 25.9% of cars are having 8 cylinders and 21.1 % of cars having 6 cylinders.

# %%
sns.scatterplot(x=data["weight"],y=data["acceleration"],data=data,hue="origin",color='red')
# Out:
# <AxesSubplot:xlabel='weight', ylabel='acceleration'>

# %% [markdown]
# ### Least weight cars are of Origin 3.and highest weight cars are of origin 1.

# %% [markdown]
# ### List out the Multivariate plots.

# %%
paiplot

# %% [markdown]
# ### Draw The Multivariate plots

# %%
sns.pairplot(data,hue='origin')

# %%
plt.figure(dpi=200)
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### from heat map we can observe that mpg and cylinders,displcement,weight are negatively correlated.

# %% [markdown]
# ### Resources for Visualization Plots
#
# https://seaborn.pydata.org/api.html for usefull information on Plots Seaborn
#
# https://www.python-graph-gallery.com/
